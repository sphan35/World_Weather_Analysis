# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of Random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d9f1fcccc084e9c4d3d01850c2920c40

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 1 | marigot
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | byron bay
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | beringovskiy
# Processing Record 12 of Set 1 | berlevag
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | vila franca do campo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | belaya gora
# Processing Record 21 of Set 1 | leningradskiy
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | alice springs
# Processing Record 25 of Set 1 | adrar
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | hervey bay
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | cabanas
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | yatou
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | sfantu gheorghe
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | lasa
# Processing Record 37 of Set 1 | portland
# Processing Record 38 of Set 1 | newport
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | taoudenni
# Processing Record 41 of Set 1 | alberton
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | la ronge
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | yerbogachen
# Processing Record 48 of Set 1 | roberval
# Processing Record 49 of Set 1 | harlingen
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | qeshm
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | morondava
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | jumla
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | caceres
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | solnechnyy
# Processing Record 13 of Set 2 | praia
# Processing Record 14 of Set 2 | maura
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | usinsk
# Processing Record 17 of Set 2 | geraldton
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | cascais
# Processing Record 23 of Set 2 | borzya
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | zhanakorgan
# Processing Record 26 of Set 2 | burnie
# Processing Record 27 of Set 2 | nishihara
# Processing Record 28 of Set 2 | grand gaube
# Processing Record 29 of Set 2 | husavik
# Processing Record 30 of Set 2 | erenhot
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | charlestown
# Processing Record 37 of Set 2 | sistranda
# Processing Record 38 of Set 2 | saint-pierre
# Processing Record 39 of Set 2 | orvieto
# Processing Record 40 of Set 2 | broken hill
# Processing Record 41 of Set 2 | loa janan
# Processing Record 42 of Set 2 | vinukonda
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | maragogi
# Processing Record 45 of Set 2 | alvorada
# Processing Record 46 of Set 2 | palu
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | haines junction
# Processing Record 49 of Set 2 | anadyr
# Processing Record 50 of Set 2 | maimon
# City not found. Skipping...
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | calama
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | acarau
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | barra do corda
# Processing Record 12 of Set 3 | menongue
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | fairbanks
# Processing Record 15 of Set 3 | yuncheng
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | xai-xai
# Processing Record 19 of Set 3 | casablanca
# Processing Record 20 of Set 3 | pangnirtung
# Processing Record 21 of Set 3 | tuatapere
# Processing Record 22 of Set 3 | vanimo
# Processing Record 23 of Set 3 | sokolo
# Processing Record 24 of Set 3 | akyab
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | port hardy
# Processing Record 27 of Set 3 | biak
# Processing Record 28 of Set 3 | luanda
# Processing Record 29 of Set 3 | seoul
# Processing Record 30 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 3 | campoverde
# Processing Record 32 of Set 3 | san carlos de bariloche
# Processing Record 33 of Set 3 | sanming
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | north platte
# Processing Record 37 of Set 3 | sakakah
# Processing Record 38 of Set 3 | los barrios
# Processing Record 39 of Set 3 | byumba
# Processing Record 40 of Set 3 | christchurch
# Processing Record 41 of Set 3 | college
# Processing Record 42 of Set 3 | curuca
# Processing Record 43 of Set 3 | sao felix do xingu
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | teya
# Processing Record 46 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 3 | ranong
# Processing Record 48 of Set 3 | itaueira
# Processing Record 49 of Set 3 | manuk mangkaw
# Processing Record 50 of Set 3 | galdar
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | kaka
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | gigmoto
# Processing Record 5 of Set 4 | mayumba
# Processing Record 6 of Set 4 | alvaraes
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | ulaangom
# Processing Record 9 of Set 4 | coxim
# Processing Record 10 of Set 4 | kang
# Processing Record 11 of Set 4 | ortakoy
# Processing Record 12 of Set 4 | boali
# Processing Record 13 of Set 4 | sehithwa
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | quchan
# Processing Record 16 of Set 4 | chokurdakh
# Processing Record 17 of Set 4 | coronado
# Processing Record 18 of Set 4 | miri
# Processing Record 19 of Set 4 | krasnovishersk
# Processing Record 20 of Set 4 | metsavan
# Processing Record 21 of Set 4 | pangai
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | ambagarh chauki
# Processing Record 27 of Set 4 | hovd
# Processing Record 28 of Set 4 | fortuna
# Processing Record 29 of Set 4 | nome
# Processing Record 30 of Set 4 | pisco
# Processing Record 31 of Set 4 | cairns
# Processing Record 32 of Set 4 | saint-louis
# Processing Record 33 of Set 4 | burns lake
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | saint-augustin
# Processing Record 36 of Set 4 | timmins
# Processing Record 37 of Set 4 | san felipe
# Processing Record 38 of Set 4 | antipovka
# Processing Record 39 of Set 4 | duldurga
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | igarka
# Processing Record 42 of Set 4 | port arthur
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | coihaique
# Processing Record 45 of Set 4 | bathsheba
# Processing Record 46 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | concarneau
# Processing Record 50 of Set 4 | ambulu
# Processing Record 1 of Set 5 | fare
# Processing Record 2 of Set 5 | chicama
# Processing Record 3 of Set 5 | spokane
# Processing Record 4 of Set 5 | wahpeton
# Processing Record 5 of Set 5 | ilulissat
# Processing Record 6 of Set 5 | duns
# Processing Record 7 of Set 5 | port hedland
# Processing Record 8 of Set 5 | dikson
# Processing Record 9 of Set 5 | jamestown
# Processing Record 10 of Set 5 | la asuncion
# Processing Record 11 of Set 5 | melfort
# Processing Record 12 of Set 5 | mayo
# Processing Record 13 of Set 5 | semnan
# Processing Record 14 of Set 5 | tuktoyaktuk
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | vardo
# Processing Record 17 of Set 5 | qaanaaq
# Processing Record 18 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 5 | mattawa
# Processing Record 20 of Set 5 | tlaxiaco
# City not found. Skipping...
# Processing Record 21 of Set 5 | lakatoro
# Processing Record 22 of Set 5 | omboue
# Processing Record 23 of Set 5 | vastseliina
# Processing Record 24 of Set 5 | jiaojiang
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | jalu
# Processing Record 27 of Set 5 | van
# Processing Record 28 of Set 5 | abu samrah
# Processing Record 29 of Set 5 | hambantota
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | angra
# City not found. Skipping...
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | ayr
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | chernenko
# Processing Record 38 of Set 5 | shibetsu
# Processing Record 39 of Set 5 | namatanai
# Processing Record 40 of Set 5 | poplar bluff
# Processing Record 41 of Set 5 | oktyabrskiy
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | broome
# Processing Record 44 of Set 5 | moyo
# Processing Record 45 of Set 5 | port-gentil
# Processing Record 46 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 5 | trairi
# Processing Record 48 of Set 5 | quatre cocos
# Processing Record 49 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 50 of Set 5 | bowmore
# Processing Record 1 of Set 6 | bereda
# Processing Record 2 of Set 6 | talaya
# Processing Record 3 of Set 6 | ancud
# Processing Record 4 of Set 6 | rajauri
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | severo-yeniseyskiy
# Processing Record 7 of Set 6 | deputatskiy
# Processing Record 8 of Set 6 | lusambo
# Processing Record 9 of Set 6 | nador
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | houma
# Processing Record 12 of Set 6 | yar-sale
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | vao
# Processing Record 15 of Set 6 | gucheng
# Processing Record 16 of Set 6 | sobolevo
# Processing Record 17 of Set 6 | tura
# Processing Record 18 of Set 6 | sokoto
# Processing Record 19 of Set 6 | bagdarin
# Processing Record 20 of Set 6 | acobamba
# Processing Record 21 of Set 6 | vodnyy
# Processing Record 22 of Set 6 | kariba
# Processing Record 23 of Set 6 | tabou
# Processing Record 24 of Set 6 | alekseyevsk
# Processing Record 25 of Set 6 | ostrovnoy
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | elizabeth city
# Processing Record 28 of Set 6 | moctezuma
# Processing Record 29 of Set 6 | ternate
# Processing Record 30 of Set 6 | venezuela
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | trelew
# Processing Record 33 of Set 6 | ovsyanka
# Processing Record 34 of Set 6 | vostok
# Processing Record 35 of Set 6 | port lincoln
# Processing Record 36 of Set 6 | sebinkarahisar
# Processing Record 37 of Set 6 | media luna
# Processing Record 38 of Set 6 | te anau
# Processing Record 39 of Set 6 | chegdomyn
# Processing Record 40 of Set 6 | knyaze-volkonskoye
# Processing Record 41 of Set 6 | suzun
# Processing Record 42 of Set 6 | mount isa
# Processing Record 43 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 6 | asau
# Processing Record 45 of Set 6 | shimoda
# Processing Record 46 of Set 6 | shakawe
# Processing Record 47 of Set 6 | mehamn
# Processing Record 48 of Set 6 | khatanga
# Processing Record 49 of Set 6 | stornoway
# Processing Record 50 of Set 6 | uzhur
# Processing Record 1 of Set 7 | alofi
# Processing Record 2 of Set 7 | saint anthony
# Processing Record 3 of Set 7 | sinnamary
# Processing Record 4 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 7 | malindi
# Processing Record 6 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 7 | paoua
# Processing Record 8 of Set 7 | buala
# Processing Record 9 of Set 7 | naze
# Processing Record 10 of Set 7 | radcliff
# Processing Record 11 of Set 7 | port keats
# Processing Record 12 of Set 7 | conde
# Processing Record 13 of Set 7 | vung tau
# Processing Record 14 of Set 7 | antofagasta
# Processing Record 15 of Set 7 | roebourne
# Processing Record 16 of Set 7 | puerto ayora
# Processing Record 17 of Set 7 | pasighat
# Processing Record 18 of Set 7 | irbeyskoye
# Processing Record 19 of Set 7 | fukue
# Processing Record 20 of Set 7 | lensk
# Processing Record 21 of Set 7 | price
# Processing Record 22 of Set 7 | jardim
# Processing Record 23 of Set 7 | noumea
# Processing Record 24 of Set 7 | qasigiannguit
# Processing Record 25 of Set 7 | rocha
# Processing Record 26 of Set 7 | batamshinskiy
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 7 | tulcingo
# City not found. Skipping...
# Processing Record 30 of Set 7 | koutsouras
# Processing Record 31 of Set 7 | osa
# Processing Record 32 of Set 7 | huangnihe
# Processing Record 33 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 34 of Set 7 | sola
# Processing Record 35 of Set 7 | boguchany
# Processing Record 36 of Set 7 | umm kaddadah
# Processing Record 37 of Set 7 | phek
# Processing Record 38 of Set 7 | lexington
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | bela
# Processing Record 41 of Set 7 | port blair
# Processing Record 42 of Set 7 | richards bay
# Processing Record 43 of Set 7 | kieta
# Processing Record 44 of Set 7 | eden
# Processing Record 45 of Set 7 | leh
# Processing Record 46 of Set 7 | pokanayevka
# City not found. Skipping...
# Processing Record 47 of Set 7 | barra patuca
# Processing Record 48 of Set 7 | kupang
# Processing Record 49 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 7 | olinda
# Processing Record 1 of Set 8 | zaraza
# Processing Record 2 of Set 8 | bubaque
# Processing Record 3 of Set 8 | ahipara
# Processing Record 4 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 8 | ocos
# Processing Record 6 of Set 8 | the valley
# Processing Record 7 of Set 8 | kommunisticheskiy
# Processing Record 8 of Set 8 | axim
# Processing Record 9 of Set 8 | kaeo
# Processing Record 10 of Set 8 | mirabad
# Processing Record 11 of Set 8 | verkh-usugli
# Processing Record 12 of Set 8 | aykhal
# Processing Record 13 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 14 of Set 8 | novikovo
# Processing Record 15 of Set 8 | nanortalik
# Processing Record 16 of Set 8 | vondrozo
# Processing Record 17 of Set 8 | savinka
# Processing Record 18 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 8 | tianpeng
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | kudahuvadhoo
# Processing Record 22 of Set 8 | vangaindrano
# Processing Record 23 of Set 8 | namibe
# Processing Record 24 of Set 8 | longfeng
# Processing Record 25 of Set 8 | west bay
# Processing Record 26 of Set 8 | monteagudo
# Processing Record 27 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 8 | kamina
# Processing Record 29 of Set 8 | malmyzh
# Processing Record 30 of Set 8 | igrim
# Processing Record 31 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 8 | gamba
# Processing Record 33 of Set 8 | yazoo city
# Processing Record 34 of Set 8 | qaqortoq
# Processing Record 35 of Set 8 | hami
# Processing Record 36 of Set 8 | wiarton
# Processing Record 37 of Set 8 | seybaplaya
# Processing Record 38 of Set 8 | kibre mengist
# Processing Record 39 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 8 | zambezi
# Processing Record 41 of Set 8 | cobija
# Processing Record 42 of Set 8 | otautau
# Processing Record 43 of Set 8 | karratha
# Processing Record 44 of Set 8 | port macquarie
# Processing Record 45 of Set 8 | male
# Processing Record 46 of Set 8 | umkomaas
# Processing Record 47 of Set 8 | san cristobal
# Processing Record 48 of Set 8 | okha
# Processing Record 49 of Set 8 | lieksa
# Processing Record 50 of Set 8 | aden
# Processing Record 1 of Set 9 | arlit
# Processing Record 2 of Set 9 | vila velha
# Processing Record 3 of Set 9 | green river
# Processing Record 4 of Set 9 | kahului
# Processing Record 5 of Set 9 | batticaloa
# Processing Record 6 of Set 9 | zapolyarnyy
# Processing Record 7 of Set 9 | vanavara
# Processing Record 8 of Set 9 | chama
# Processing Record 9 of Set 9 | ucluelet
# Processing Record 10 of Set 9 | el corozal
# Processing Record 11 of Set 9 | porto nacional
# Processing Record 12 of Set 9 | abha
# Processing Record 13 of Set 9 | iquique
# Processing Record 14 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 9 | nouadhibou
# Processing Record 16 of Set 9 | port augusta
# Processing Record 17 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 9 | aranos
# Processing Record 20 of Set 9 | straldza
# City not found. Skipping...
# Processing Record 21 of Set 9 | salisbury
# Processing Record 22 of Set 9 | payakumbuh
# Processing Record 23 of Set 9 | klaeng
# Processing Record 24 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 9 | guarapari
# Processing Record 26 of Set 9 | sayaxche
# Processing Record 27 of Set 9 | eregli
# Processing Record 28 of Set 9 | ziarat
# Processing Record 29 of Set 9 | orange cove
# Processing Record 30 of Set 9 | kruisfontein
# Processing Record 31 of Set 9 | zhigansk
# Processing Record 32 of Set 9 | moussoro
# Processing Record 33 of Set 9 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 34 of Set 9 | malayal
# Processing Record 35 of Set 9 | wigtown
# Processing Record 36 of Set 9 | mendeleyevo
# Processing Record 37 of Set 9 | erzin
# Processing Record 38 of Set 9 | lata
# Processing Record 39 of Set 9 | airai
# Processing Record 40 of Set 9 | mookane
# Processing Record 41 of Set 9 | camacha
# Processing Record 42 of Set 9 | fort frances
# Processing Record 43 of Set 9 | bryan
# Processing Record 44 of Set 9 | taranto
# Processing Record 45 of Set 9 | lompoc
# Processing Record 46 of Set 9 | talnakh
# Processing Record 47 of Set 9 | bose
# Processing Record 48 of Set 9 | fort nelson
# Processing Record 49 of Set 9 | cartagena
# Processing Record 50 of Set 9 | trapani
# Processing Record 1 of Set 10 | avera
# Processing Record 2 of Set 10 | liapades
# City not found. Skipping...
# Processing Record 3 of Set 10 | garchitorena
# Processing Record 4 of Set 10 | perbaungan
# Processing Record 5 of Set 10 | eydhafushi
# Processing Record 6 of Set 10 | launceston
# Processing Record 7 of Set 10 | ambunti
# Processing Record 8 of Set 10 | cuiluan
# Processing Record 9 of Set 10 | coahuayana
# Processing Record 10 of Set 10 | letlhakane
# Processing Record 11 of Set 10 | arkhipo-osipovka
# Processing Record 12 of Set 10 | kushmurun
# Processing Record 13 of Set 10 | plettenberg bay
# Processing Record 14 of Set 10 | nouakchott
# Processing Record 15 of Set 10 | kirakira
# Processing Record 16 of Set 10 | sokode
# Processing Record 17 of Set 10 | koumac
# Processing Record 18 of Set 10 | jasper
# Processing Record 19 of Set 10 | beloha
# Processing Record 20 of Set 10 | phu ly
# Processing Record 21 of Set 10 | san quintin
# Processing Record 22 of Set 10 | centralia
# Processing Record 23 of Set 10 | ust-maya
# Processing Record 24 of Set 10 | kitimat
# Processing Record 25 of Set 10 | guanica
# Processing Record 26 of Set 10 | prince george
# Processing Record 27 of Set 10 | balabac
# Processing Record 28 of Set 10 | jaciara
# Processing Record 29 of Set 10 | las vegas
# Processing Record 30 of Set 10 | piacabucu
# Processing Record 31 of Set 10 | luzhou
# Processing Record 32 of Set 10 | kiunga
# Processing Record 33 of Set 10 | leshukonskoye
# Processing Record 34 of Set 10 | okhotsk
# Processing Record 35 of Set 10 | palmer
# Processing Record 36 of Set 10 | goya
# Processing Record 37 of Set 10 | boyolangu
# Processing Record 38 of Set 10 | mwene-ditu
# Processing Record 39 of Set 10 | clyde river
# Processing Record 40 of Set 10 | rogun
# City not found. Skipping...
# Processing Record 41 of Set 10 | neiafu
# Processing Record 42 of Set 10 | dunedin
# Processing Record 43 of Set 10 | ekhabi
# Processing Record 44 of Set 10 | muros
# Processing Record 45 of Set 10 | kailua
# Processing Record 46 of Set 10 | emba
# Processing Record 47 of Set 10 | kemijarvi
# Processing Record 48 of Set 10 | ziro
# Processing Record 49 of Set 10 | haapiti
# Processing Record 50 of Set 10 | paraiso
# Processing Record 1 of Set 11 | bengkulu
# Processing Record 2 of Set 11 | whitley bay
# Processing Record 3 of Set 11 | mareeba
# Processing Record 4 of Set 11 | hay river
# Processing Record 5 of Set 11 | roberto payan
# City not found. Skipping...
# Processing Record 6 of Set 11 | sioux lookout
# Processing Record 7 of Set 11 | qandala
# Processing Record 8 of Set 11 | wanaka
# Processing Record 9 of Set 11 | marsa matruh
# Processing Record 10 of Set 11 | mandalgovi
# Processing Record 11 of Set 11 | praia da vitoria
# Processing Record 12 of Set 11 | sambava
# Processing Record 13 of Set 11 | nieuw amsterdam
# Processing Record 14 of Set 11 | madison
# Processing Record 15 of Set 11 | amahai
# Processing Record 16 of Set 11 | seabra
# Processing Record 17 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 18 of Set 11 | najran
# Processing Record 19 of Set 11 | salinas
# Processing Record 20 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 22 of Set 11 | isiro
# Processing Record 23 of Set 11 | inhambane
# Processing Record 24 of Set 11 | x-can
# City not found. Skipping...
# Processing Record 25 of Set 11 | berdigestyakh
# Processing Record 26 of Set 11 | phan thiet
# Processing Record 27 of Set 11 | birin
# Processing Record 28 of Set 11 | cortez
# Processing Record 29 of Set 11 | srednekolymsk
# Processing Record 30 of Set 11 | filingue
# Processing Record 31 of Set 11 | almaznyy
# Processing Record 32 of Set 11 | bodmin
# Processing Record 33 of Set 11 | matara
# Processing Record 34 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 11 | saint-francois
# Processing Record 36 of Set 11 | whitianga
# Processing Record 37 of Set 11 | kogon
# Processing Record 38 of Set 11 | bandarbeyla
# Processing Record 39 of Set 11 | znamenskoye
# Processing Record 40 of Set 11 | miraflores
# Processing Record 41 of Set 11 | nalut
# Processing Record 42 of Set 11 | viedma
# Processing Record 43 of Set 11 | nago
# Processing Record 44 of Set 11 | antalaha
# Processing Record 45 of Set 11 | agirish
# Processing Record 46 of Set 11 | santa ines
# Processing Record 47 of Set 11 | ponta delgada
# Processing Record 48 of Set 11 | atikokan
# Processing Record 49 of Set 11 | havoysund
# Processing Record 50 of Set 11 | touros
# Processing Record 1 of Set 12 | waingapu
# Processing Record 2 of Set 12 | netanya
# Processing Record 3 of Set 12 | kenai
# Processing Record 4 of Set 12 | juigalpa
# Processing Record 5 of Set 12 | miram shah
# Processing Record 6 of Set 12 | kasongo-lunda
# Processing Record 7 of Set 12 | svetlyy
# Processing Record 8 of Set 12 | maceio
# Processing Record 9 of Set 12 | gizo
# Processing Record 10 of Set 12 | poum
# Processing Record 11 of Set 12 | verkhnyaya inta
# Processing Record 12 of Set 12 | bichena
# Processing Record 13 of Set 12 | awjilah
# Processing Record 14 of Set 12 | athni
# Processing Record 15 of Set 12 | steamboat springs
# Processing Record 16 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 12 | areia branca
# Processing Record 18 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 12 | griffith
# Processing Record 20 of Set 12 | homer
# Processing Record 21 of Set 12 | mayfield
# Processing Record 22 of Set 12 | narrabri
# Processing Record 23 of Set 12 | shingu
# Processing Record 24 of Set 12 | kungurtug
# Processing Record 25 of Set 12 | rio grande
# Processing Record 26 of Set 12 | jizan
# Processing Record 27 of Set 12 | manali
# Processing Record 28 of Set 12 | manassas park
# Processing Record 29 of Set 12 | vorukh
# Processing Record 30 of Set 12 | grindavik
# Processing Record 31 of Set 12 | caibarien
# Processing Record 32 of Set 12 | itoman
# Processing Record 33 of Set 12 | kingsville
# Processing Record 34 of Set 12 | tautira
# Processing Record 35 of Set 12 | placido de castro
# Processing Record 36 of Set 12 | nizhniy tsasuchey
# Processing Record 37 of Set 12 | san vicente
# Processing Record 38 of Set 12 | richmond
# Processing Record 39 of Set 12 | salur
# Processing Record 40 of Set 12 | sorland
# Processing Record 41 of Set 12 | labuan
# Processing Record 42 of Set 12 | lively
# Processing Record 43 of Set 12 | marrakesh
# Processing Record 44 of Set 12 | tilichiki
# Processing Record 45 of Set 12 | bilibino
# Processing Record 46 of Set 12 | mairana
# Processing Record 47 of Set 12 | sotouboua
# Processing Record 48 of Set 12 | alugan
# Processing Record 49 of Set 12 | harper
# Processing Record 50 of Set 12 | cockburn town
# Processing Record 1 of Set 13 | tezu
# Processing Record 2 of Set 13 | maan
# Processing Record 3 of Set 13 | da nang
# Processing Record 4 of Set 13 | mogadishu
# Processing Record 5 of Set 13 | zaysan
# Processing Record 6 of Set 13 | rawson
# Processing Record 7 of Set 13 | rio verde de mato grosso
# Processing Record 8 of Set 13 | sirajganj
# Processing Record 9 of Set 13 | antigonish
# Processing Record 10 of Set 13 | kazachinskoye
# Processing Record 11 of Set 13 | astoria
# Processing Record 12 of Set 13 | athabasca
# Processing Record 13 of Set 13 | harindanga
# Processing Record 14 of Set 13 | alekseyevka
# Processing Record 15 of Set 13 | libertad
# Processing Record 16 of Set 13 | chulman
# Processing Record 17 of Set 13 | port-cartier
# Processing Record 18 of Set 13 | aizkraukle
# Processing Record 19 of Set 13 | tyukalinsk
# Processing Record 20 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 13 | biggar
# Processing Record 22 of Set 13 | fernie
# Processing Record 23 of Set 13 | oudtshoorn
# Processing Record 24 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 25 of Set 13 | padang
# Processing Record 26 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 13 | margate
# Processing Record 28 of Set 13 | nadym
# Processing Record 29 of Set 13 | sozopolis
# City not found. Skipping...
# Processing Record 30 of Set 13 | san mariano
# Processing Record 31 of Set 13 | bartica
# Processing Record 32 of Set 13 | chapais
# Processing Record 33 of Set 13 | tupik
# Processing Record 34 of Set 13 | kahramanmaras
# Processing Record 35 of Set 13 | kavieng
# Processing Record 36 of Set 13 | angoche
# Processing Record 37 of Set 13 | neuquen
# Processing Record 38 of Set 13 | dzilam gonzalez
# Processing Record 39 of Set 13 | xiongyue
# Processing Record 40 of Set 13 | bonfim
# Processing Record 41 of Set 13 | pangkalanbuun
# Processing Record 42 of Set 13 | meadow lake
# Processing Record 43 of Set 13 | general roca
# Processing Record 44 of Set 13 | lazaro cardenas
# Processing Record 45 of Set 13 | elesbao veloso
# Processing Record 46 of Set 13 | zharkent
# Processing Record 47 of Set 13 | santa maria do para
# Processing Record 48 of Set 13 | tagusao
# Processing Record 49 of Set 13 | mora
# Processing Record 50 of Set 13 | reconquista
# Processing Record 1 of Set 14 | itaituba
# Processing Record 2 of Set 14 | santa rosa del sur
# Processing Record 3 of Set 14 | la primavera
# Processing Record 4 of Set 14 | tecoanapa
# Processing Record 5 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 6 of Set 14 | evensk
# Processing Record 7 of Set 14 | jawhar
# Processing Record 8 of Set 14 | clearwater
# Processing Record 9 of Set 14 | belyy yar
# Processing Record 10 of Set 14 | maine-soroa
# Processing Record 11 of Set 14 | wagar
# Processing Record 12 of Set 14 | bria
# Processing Record 13 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 14 | columbus
# Processing Record 15 of Set 14 | batagay
# Processing Record 16 of Set 14 | gat
# Processing Record 17 of Set 14 | montepuez
# Processing Record 18 of Set 14 | salcininkai
# Processing Record 19 of Set 14 | cabra
# Processing Record 20 of Set 14 | gravelbourg
# Processing Record 21 of Set 14 | berbera
# Processing Record 22 of Set 14 | seymchan
# Processing Record 23 of Set 14 | shahr-e babak
# Processing Record 24 of Set 14 | tual
# Processing Record 25 of Set 14 | murray bridge
# Processing Record 26 of Set 14 | waipawa
# Processing Record 27 of Set 14 | buta
# Processing Record 28 of Set 14 | sukpak
# Processing Record 29 of Set 14 | shikarpur
# Processing Record 30 of Set 14 | banff
# Processing Record 31 of Set 14 | lakota
# Processing Record 32 of Set 14 | katherine
# Processing Record 33 of Set 14 | artsvanist
# Processing Record 34 of Set 14 | phangnga
# Processing Record 35 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 14 | marsh harbour
# Processing Record 37 of Set 14 | korampallam
# Processing Record 38 of Set 14 | phichit
# Processing Record 39 of Set 14 | thabazimbi
# Processing Record 40 of Set 14 | hofn
# Processing Record 41 of Set 14 | cururupu
# Processing Record 42 of Set 14 | isangel
# Processing Record 43 of Set 14 | banda aceh
# Processing Record 44 of Set 14 | sikasso
# Processing Record 45 of Set 14 | orlik
# Processing Record 46 of Set 14 | novoagansk
# Processing Record 47 of Set 14 | doha
# Processing Record 48 of Set 14 | tessalit
# Processing Record 49 of Set 14 | baykit
# Processing Record 50 of Set 14 | sungaipenuh
# Processing Record 1 of Set 15 | dongsheng
# Processing Record 2 of Set 15 | smolenka
# Processing Record 3 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 15 | moose factory
# Processing Record 5 of Set 15 | uaua
# Processing Record 6 of Set 15 | korem
# Processing Record 7 of Set 15 | saryg-sep
# Processing Record 8 of Set 15 | awbari
# Processing Record 9 of Set 15 | buritama
# Processing Record 10 of Set 15 | selenginsk
# Processing Record 11 of Set 15 | westport
# Processing Record 12 of Set 15 | santa luzia
# Processing Record 13 of Set 15 | pedro ii
# Processing Record 14 of Set 15 | kamaishi
# Processing Record 15 of Set 15 | quang ngai
# Processing Record 16 of Set 15 | santa lucia
# Processing Record 17 of Set 15 | mattru
# Processing Record 18 of Set 15 | hellvik
# Processing Record 19 of Set 15 | bukama
# Processing Record 20 of Set 15 | bontang
# Processing Record 21 of Set 15 | sayyan
# Processing Record 22 of Set 15 | comodoro rivadavia
# Processing Record 23 of Set 15 | ust-ilimsk
# Processing Record 24 of Set 15 | pozo colorado
# Processing Record 25 of Set 15 | flin flon
# Processing Record 26 of Set 15 | constitucion
# Processing Record 27 of Set 15 | dali
# Processing Record 28 of Set 15 | zheleznodorozhnyy
# Processing Record 29 of Set 15 | khovu-aksy
# Processing Record 30 of Set 15 | necochea
# Processing Record 31 of Set 15 | barcelos
# Processing Record 32 of Set 15 | shimanovsk
# Processing Record 33 of Set 15 | susurluk
# Processing Record 34 of Set 15 | celestun
# Processing Record 35 of Set 15 | denpasar
# Processing Record 36 of Set 15 | mount gambier
# Processing Record 37 of Set 15 | biloela
# Processing Record 38 of Set 15 | catuday
# Processing Record 39 of Set 15 | kasempa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Torbay  47.67  -52.73     33.01        68          75        8.05
# 1     Esperance -33.87  121.90     57.20        82          98       10.29
# 2       Marigot  18.07  -63.08     80.60        78          75       11.41
# 3        Barrow  71.29 -156.79     21.20        85          90       14.99
# 4     Busselton -33.65  115.33     61.00        51           0       15.90
# 5     Byron Bay -28.65  153.62     75.00        52          40       18.34
# 6       Rikitea -23.12 -134.97     74.55        69          20       12.71
# 7         Vaini -21.20 -175.20     80.60        69          20       13.87
# 8  Beringovskiy  63.05  179.32     37.22        93         100       22.57
# 9      Berlevag  70.86   29.09     39.58        84          76        6.80
#
#   Country Current Description
# 0      CA       broken clouds
# 1      AU     overcast clouds
# 2      MF       broken clouds
# 3      US     overcast clouds
# 4      AU           clear sky
# 5      AU    scattered clouds
# 6      PF          few clouds
# 7      TO          few clouds
# 8      RU     overcast clouds
# 9      NO       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Torbay      CA  47.67  -52.73     33.01        68          75
# 1        Esperance      AU -33.87  121.90     57.20        82          98
# 2          Marigot      MF  18.07  -63.08     80.60        78          75
# 3           Barrow      US  71.29 -156.79     21.20        85          90
# 4        Busselton      AU -33.65  115.33     61.00        51           0
# ..             ...     ...    ...     ...       ...       ...         ...
# 675       Denpasar      ID  -8.65  115.22     80.56        75           9
# 676  Mount Gambier      AU -37.83  140.77     55.40        71          75
# 677        Biloela      AU -24.42  150.50     79.36        20           0
# 678        Catuday      PH  16.29  119.81     78.82        81         100
# 679        Kasempa      ZM -13.46   25.83     66.67        60          23
#
#      Wind Speed Current Description
# 0          8.05       broken clouds
# 1         10.29     overcast clouds
# 2         11.41       broken clouds
# 3         14.99     overcast clouds
# 4         15.90           clear sky
# ..          ...                 ...
# 675        0.96           clear sky
# 676        9.17       broken clouds
# 677       10.63           clear sky
# 678        4.09     overcast clouds
# 679        2.37          few clouds
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
