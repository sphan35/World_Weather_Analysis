# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of Random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d9f1fcccc084e9c4d3d01850c2920c40

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | virginia beach
# Processing Record 6 of Set 1 | nakhon thai
# Processing Record 7 of Set 1 | dubuque
# Processing Record 8 of Set 1 | lincoln
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | vila velha
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | gouyave
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | dawan
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | dali
# Processing Record 20 of Set 1 | zacualpan
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 1 | athabasca
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | sao joao da barra
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | thunder bay
# Processing Record 32 of Set 1 | gull lake
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | japura
# Processing Record 37 of Set 1 | sinnamary
# Processing Record 38 of Set 1 | goderich
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | susanville
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | kamiiso
# Processing Record 44 of Set 1 | salalah
# Processing Record 45 of Set 1 | san andres
# Processing Record 46 of Set 1 | los llanos de aridane
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | mabaruma
# Processing Record 49 of Set 1 | worland
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | axim
# Processing Record 2 of Set 2 | katsuura
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | saint george
# Processing Record 5 of Set 2 | lerwick
# Processing Record 6 of Set 2 | cayenne
# Processing Record 7 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 2 | jati
# Processing Record 9 of Set 2 | coihaique
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | staro nagoricane
# City not found. Skipping...
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | buderim
# Processing Record 14 of Set 2 | altay
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | saint-pierre
# Processing Record 17 of Set 2 | mangai
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | tautira
# Processing Record 20 of Set 2 | strelka
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | puerto triunfo
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | mbanza-ngungu
# Processing Record 29 of Set 2 | okhotsk
# Processing Record 30 of Set 2 | leningradskiy
# Processing Record 31 of Set 2 | ust-kuyga
# Processing Record 32 of Set 2 | angoram
# Processing Record 33 of Set 2 | canico
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | xining
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | torun
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | tanshui
# City not found. Skipping...
# Processing Record 41 of Set 2 | acarau
# Processing Record 42 of Set 2 | jumla
# Processing Record 43 of Set 2 | quelimane
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | haines junction
# Processing Record 47 of Set 2 | upata
# Processing Record 48 of Set 2 | faanui
# Processing Record 49 of Set 2 | maniitsoq
# Processing Record 50 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | natal
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | tuatapere
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | port said
# Processing Record 7 of Set 3 | usoke
# Processing Record 8 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 3 | radomsko
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | saint pete beach
# Processing Record 13 of Set 3 | quatre cocos
# Processing Record 14 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 3 | naryan-mar
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 3 | ostrovnoy
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | cockburn town
# Processing Record 21 of Set 3 | itarema
# Processing Record 22 of Set 3 | bolonchen
# City not found. Skipping...
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | bubaque
# Processing Record 25 of Set 3 | lyuban
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | teguldet
# Processing Record 28 of Set 3 | kismayo
# Processing Record 29 of Set 3 | isangel
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | san ignacio
# Processing Record 32 of Set 3 | aksarka
# Processing Record 33 of Set 3 | akdepe
# Processing Record 34 of Set 3 | obarsia-closani
# City not found. Skipping...
# Processing Record 35 of Set 3 | breyten
# Processing Record 36 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | porto novo
# Processing Record 40 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | beringovskiy
# Processing Record 42 of Set 3 | lichuan
# Processing Record 43 of Set 3 | mapiripan
# Processing Record 44 of Set 3 | hluti
# Processing Record 45 of Set 3 | freeport
# Processing Record 46 of Set 3 | nantucket
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | kamina
# Processing Record 50 of Set 3 | verkhoyansk
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | kawalu
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 4 | neiafu
# Processing Record 6 of Set 4 | chongwe
# Processing Record 7 of Set 4 | cao bang
# Processing Record 8 of Set 4 | kasongo-lunda
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 4 | stokmarknes
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | belmonte
# Processing Record 14 of Set 4 | revelstoke
# Processing Record 15 of Set 4 | vicksburg
# Processing Record 16 of Set 4 | naron
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | khatanga
# Processing Record 19 of Set 4 | moree
# Processing Record 20 of Set 4 | okoneshnikovo
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | sikandra
# Processing Record 23 of Set 4 | fuzhou
# Processing Record 24 of Set 4 | northam
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | hami
# Processing Record 27 of Set 4 | kahului
# Processing Record 28 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 4 | zermatt
# Processing Record 30 of Set 4 | touros
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | prince rupert
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | okato
# Processing Record 35 of Set 4 | meteti
# Processing Record 36 of Set 4 | abaza
# Processing Record 37 of Set 4 | kiama
# Processing Record 38 of Set 4 | ust-barguzin
# Processing Record 39 of Set 4 | hammerfest
# Processing Record 40 of Set 4 | tazovskiy
# Processing Record 41 of Set 4 | luanda
# Processing Record 42 of Set 4 | gorodishche
# Processing Record 43 of Set 4 | wynyard
# Processing Record 44 of Set 4 | saint-georges
# Processing Record 45 of Set 4 | boke
# Processing Record 46 of Set 4 | cunha
# Processing Record 47 of Set 4 | chabua
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | olinda
# Processing Record 50 of Set 4 | saint-augustin
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 5 | borogontsy
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | atuona
# Processing Record 6 of Set 5 | eyrarbakki
# Processing Record 7 of Set 5 | anjiang
# Processing Record 8 of Set 5 | tuktoyaktuk
# Processing Record 9 of Set 5 | toamasina
# Processing Record 10 of Set 5 | laurel
# Processing Record 11 of Set 5 | kaitangata
# Processing Record 12 of Set 5 | qaqortoq
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | huarmey
# Processing Record 15 of Set 5 | tilichiki
# Processing Record 16 of Set 5 | richards bay
# Processing Record 17 of Set 5 | buraydah
# Processing Record 18 of Set 5 | badaojiang
# City not found. Skipping...
# Processing Record 19 of Set 5 | tadine
# Processing Record 20 of Set 5 | cap malheureux
# Processing Record 21 of Set 5 | collie
# Processing Record 22 of Set 5 | bredasdorp
# Processing Record 23 of Set 5 | najran
# Processing Record 24 of Set 5 | chumikan
# Processing Record 25 of Set 5 | tamandare
# Processing Record 26 of Set 5 | skibbereen
# Processing Record 27 of Set 5 | gazanjyk
# Processing Record 28 of Set 5 | buchanan
# Processing Record 29 of Set 5 | arona
# Processing Record 30 of Set 5 | vardo
# Processing Record 31 of Set 5 | yashkul
# Processing Record 32 of Set 5 | ewing
# Processing Record 33 of Set 5 | flin flon
# Processing Record 34 of Set 5 | trussville
# Processing Record 35 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 5 | laguna
# Processing Record 37 of Set 5 | kirovohrad
# Processing Record 38 of Set 5 | finspang
# Processing Record 39 of Set 5 | guerrero negro
# Processing Record 40 of Set 5 | puerto baquerizo moreno
# Processing Record 41 of Set 5 | camacha
# Processing Record 42 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 43 of Set 5 | pevek
# Processing Record 44 of Set 5 | faya
# Processing Record 45 of Set 5 | hithadhoo
# Processing Record 46 of Set 5 | satinka
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | skelleftea
# Processing Record 49 of Set 5 | hamilton
# Processing Record 50 of Set 5 | tarakan
# Processing Record 1 of Set 6 | yar-sale
# Processing Record 2 of Set 6 | mahebourg
# Processing Record 3 of Set 6 | te anau
# Processing Record 4 of Set 6 | sungurlu
# Processing Record 5 of Set 6 | miranda
# Processing Record 6 of Set 6 | sitka
# Processing Record 7 of Set 6 | grindavik
# Processing Record 8 of Set 6 | kibiti
# Processing Record 9 of Set 6 | huilong
# Processing Record 10 of Set 6 | danielskuil
# Processing Record 11 of Set 6 | koslan
# Processing Record 12 of Set 6 | digras
# Processing Record 13 of Set 6 | ixtapa
# Processing Record 14 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 6 | bengkulu
# Processing Record 16 of Set 6 | bwanga
# Processing Record 17 of Set 6 | krasnoturansk
# Processing Record 18 of Set 6 | stykkisholmur
# Processing Record 19 of Set 6 | yulara
# Processing Record 20 of Set 6 | yuncheng
# Processing Record 21 of Set 6 | grand gaube
# Processing Record 22 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 6 | talakan
# Processing Record 24 of Set 6 | brae
# Processing Record 25 of Set 6 | denia
# Processing Record 26 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 6 | sola
# Processing Record 29 of Set 6 | tokmak
# Processing Record 30 of Set 6 | geraldton
# Processing Record 31 of Set 6 | lesnoy
# Processing Record 32 of Set 6 | boa vista
# Processing Record 33 of Set 6 | russell
# Processing Record 34 of Set 6 | micheweni
# Processing Record 35 of Set 6 | mayo
# Processing Record 36 of Set 6 | hirara
# Processing Record 37 of Set 6 | jasper
# Processing Record 38 of Set 6 | lelystad
# Processing Record 39 of Set 6 | nabire
# Processing Record 40 of Set 6 | togur
# Processing Record 41 of Set 6 | singkang
# Processing Record 42 of Set 6 | ucluelet
# Processing Record 43 of Set 6 | aklavik
# Processing Record 44 of Set 6 | nanakuli
# Processing Record 45 of Set 6 | nome
# Processing Record 46 of Set 6 | swan hill
# Processing Record 47 of Set 6 | caconda
# Processing Record 48 of Set 6 | orlik
# Processing Record 49 of Set 6 | souillac
# Processing Record 50 of Set 6 | samarai
# Processing Record 1 of Set 7 | neverkino
# Processing Record 2 of Set 7 | sterling
# Processing Record 3 of Set 7 | ust-omchug
# Processing Record 4 of Set 7 | toropets
# Processing Record 5 of Set 7 | port hardy
# Processing Record 6 of Set 7 | long xuyen
# Processing Record 7 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | paamiut
# Processing Record 9 of Set 7 | meulaboh
# Processing Record 10 of Set 7 | auki
# Processing Record 11 of Set 7 | fairbanks
# Processing Record 12 of Set 7 | kashi
# Processing Record 13 of Set 7 | bitung
# Processing Record 14 of Set 7 | chikoy
# City not found. Skipping...
# Processing Record 15 of Set 7 | trairi
# Processing Record 16 of Set 7 | koulikoro
# Processing Record 17 of Set 7 | azuqueca de henares
# Processing Record 18 of Set 7 | inuvik
# Processing Record 19 of Set 7 | nakamura
# Processing Record 20 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 7 | westport
# Processing Record 22 of Set 7 | adre
# Processing Record 23 of Set 7 | bud
# Processing Record 24 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 7 | arraias
# Processing Record 26 of Set 7 | santa rosa
# Processing Record 27 of Set 7 | saint-joseph
# Processing Record 28 of Set 7 | dandong
# Processing Record 29 of Set 7 | coahuayana
# Processing Record 30 of Set 7 | mutoko
# Processing Record 31 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 7 | srivardhan
# Processing Record 33 of Set 7 | abonnema
# Processing Record 34 of Set 7 | kjollefjord
# Processing Record 35 of Set 7 | acapulco
# Processing Record 36 of Set 7 | praia
# Processing Record 37 of Set 7 | san patricio
# Processing Record 38 of Set 7 | castelnaudary
# Processing Record 39 of Set 7 | grand-santi
# Processing Record 40 of Set 7 | saskylakh
# Processing Record 41 of Set 7 | hambantota
# Processing Record 42 of Set 7 | novikovo
# Processing Record 43 of Set 7 | gardez
# Processing Record 44 of Set 7 | new ulm
# Processing Record 45 of Set 7 | we
# City not found. Skipping...
# Processing Record 46 of Set 7 | katobu
# Processing Record 47 of Set 7 | nanortalik
# Processing Record 48 of Set 7 | ozernovskiy
# Processing Record 49 of Set 7 | atyrau
# Processing Record 50 of Set 7 | gravdal
# Processing Record 1 of Set 8 | taltal
# Processing Record 2 of Set 8 | saldanha
# Processing Record 3 of Set 8 | samana
# Processing Record 4 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 8 | pedernales
# Processing Record 6 of Set 8 | orestias
# City not found. Skipping...
# Processing Record 7 of Set 8 | ballina
# Processing Record 8 of Set 8 | rathkeale
# Processing Record 9 of Set 8 | kavieng
# Processing Record 10 of Set 8 | palu
# Processing Record 11 of Set 8 | mainit
# Processing Record 12 of Set 8 | byron bay
# Processing Record 13 of Set 8 | shahrud
# Processing Record 14 of Set 8 | el badari
# City not found. Skipping...
# Processing Record 15 of Set 8 | lucapa
# Processing Record 16 of Set 8 | sao jose da coroa grande
# Processing Record 17 of Set 8 | toccoa
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 8 | merauke
# Processing Record 21 of Set 8 | chapleau
# Processing Record 22 of Set 8 | kodinsk
# Processing Record 23 of Set 8 | sistranda
# Processing Record 24 of Set 8 | broome
# Processing Record 25 of Set 8 | murupara
# Processing Record 26 of Set 8 | hanover
# Processing Record 27 of Set 8 | immokalee
# Processing Record 28 of Set 8 | ankang
# Processing Record 29 of Set 8 | yarmouth
# Processing Record 30 of Set 8 | luderitz
# Processing Record 31 of Set 8 | clyde river
# Processing Record 32 of Set 8 | ambulu
# Processing Record 33 of Set 8 | alta floresta
# Processing Record 34 of Set 8 | msanga
# Processing Record 35 of Set 8 | ust-nera
# Processing Record 36 of Set 8 | isabela
# Processing Record 37 of Set 8 | resistencia
# Processing Record 38 of Set 8 | anadyr
# Processing Record 39 of Set 8 | grafton
# Processing Record 40 of Set 8 | namibe
# Processing Record 41 of Set 8 | ames
# Processing Record 42 of Set 8 | deputatskiy
# Processing Record 43 of Set 8 | dunedin
# Processing Record 44 of Set 8 | turukhansk
# Processing Record 45 of Set 8 | devils lake
# Processing Record 46 of Set 8 | gao
# Processing Record 47 of Set 8 | airai
# Processing Record 48 of Set 8 | luena
# Processing Record 49 of Set 8 | zhigansk
# Processing Record 50 of Set 8 | east wenatchee bench
# Processing Record 1 of Set 9 | yingcheng
# Processing Record 2 of Set 9 | sicamous
# Processing Record 3 of Set 9 | klaksvik
# Processing Record 4 of Set 9 | dilla
# Processing Record 5 of Set 9 | itaituba
# Processing Record 6 of Set 9 | kabalo
# Processing Record 7 of Set 9 | waipawa
# Processing Record 8 of Set 9 | pisco
# Processing Record 9 of Set 9 | marsh harbour
# Processing Record 10 of Set 9 | christchurch
# Processing Record 11 of Set 9 | la reforma
# Processing Record 12 of Set 9 | hofn
# Processing Record 13 of Set 9 | trindade
# Processing Record 14 of Set 9 | iwanai
# Processing Record 15 of Set 9 | china
# Processing Record 16 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 9 | pudozh
# Processing Record 18 of Set 9 | amga
# Processing Record 19 of Set 9 | labuhan
# Processing Record 20 of Set 9 | raga
# Processing Record 21 of Set 9 | kyra
# Processing Record 22 of Set 9 | lermontovka
# Processing Record 23 of Set 9 | ivanava
# Processing Record 24 of Set 9 | egvekinot
# Processing Record 25 of Set 9 | nemuro
# Processing Record 26 of Set 9 | arlit
# Processing Record 27 of Set 9 | alice springs
# Processing Record 28 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 9 | pincher creek
# Processing Record 30 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 9 | plouzane
# Processing Record 32 of Set 9 | shimoda
# Processing Record 33 of Set 9 | narsaq
# Processing Record 34 of Set 9 | port-cartier
# Processing Record 35 of Set 9 | tiarei
# Processing Record 36 of Set 9 | pishin
# Processing Record 37 of Set 9 | coquimbo
# Processing Record 38 of Set 9 | ketchikan
# Processing Record 39 of Set 9 | saquena
# Processing Record 40 of Set 9 | kolpny
# Processing Record 41 of Set 9 | port elizabeth
# Processing Record 42 of Set 9 | peniche
# Processing Record 43 of Set 9 | puerto escondido
# Processing Record 44 of Set 9 | guiratinga
# Processing Record 45 of Set 9 | inta
# Processing Record 46 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 9 | kaabong
# Processing Record 48 of Set 9 | port moresby
# Processing Record 49 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 9 | andenes
# Processing Record 1 of Set 10 | dingle
# Processing Record 2 of Set 10 | jinchang
# Processing Record 3 of Set 10 | tura
# Processing Record 4 of Set 10 | kisangani
# Processing Record 5 of Set 10 | havre-saint-pierre
# Processing Record 6 of Set 10 | vostok
# Processing Record 7 of Set 10 | batticaloa
# Processing Record 8 of Set 10 | komsomolskiy
# Processing Record 9 of Set 10 | las lomas
# Processing Record 10 of Set 10 | pemangkat
# Processing Record 11 of Set 10 | flinders
# Processing Record 12 of Set 10 | carballo
# Processing Record 13 of Set 10 | erenhot
# Processing Record 14 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 10 | arambagh
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | fortuna
# Processing Record 18 of Set 10 | boden
# Processing Record 19 of Set 10 | villa rica
# Processing Record 20 of Set 10 | banff
# Processing Record 21 of Set 10 | vidim
# Processing Record 22 of Set 10 | yamada
# Processing Record 23 of Set 10 | punta alta
# Processing Record 24 of Set 10 | constitucion
# Processing Record 25 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 26 of Set 10 | makat
# Processing Record 27 of Set 10 | ekibastuz
# Processing Record 28 of Set 10 | berlevag
# Processing Record 29 of Set 10 | iquitos
# Processing Record 30 of Set 10 | campoverde
# Processing Record 31 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 32 of Set 10 | mumford
# Processing Record 33 of Set 10 | puerto princesa
# Processing Record 34 of Set 10 | marsa matruh
# Processing Record 35 of Set 10 | hay river
# Processing Record 36 of Set 10 | corbelia
# Processing Record 37 of Set 10 | anchorage
# Processing Record 38 of Set 10 | houma
# Processing Record 39 of Set 10 | marfino
# Processing Record 40 of Set 10 | dalbandin
# Processing Record 41 of Set 10 | port hedland
# Processing Record 42 of Set 10 | trat
# Processing Record 43 of Set 10 | mali
# Processing Record 44 of Set 10 | bani
# Processing Record 45 of Set 10 | sobolevo
# Processing Record 46 of Set 10 | bathsheba
# Processing Record 47 of Set 10 | srednekolymsk
# Processing Record 48 of Set 10 | nampula
# Processing Record 49 of Set 10 | kwinana
# Processing Record 50 of Set 10 | jiayuguan
# Processing Record 1 of Set 11 | newport
# Processing Record 2 of Set 11 | verkhnevilyuysk
# Processing Record 3 of Set 11 | biltine
# Processing Record 4 of Set 11 | smoljan
# Processing Record 5 of Set 11 | kalininsk
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | chapais
# Processing Record 8 of Set 11 | mookane
# Processing Record 9 of Set 11 | oshawa
# Processing Record 10 of Set 11 | fontaine
# Processing Record 11 of Set 11 | bukachacha
# Processing Record 12 of Set 11 | la trinitaria
# Processing Record 13 of Set 11 | mehamn
# Processing Record 14 of Set 11 | muisne
# Processing Record 15 of Set 11 | kurchaloy
# Processing Record 16 of Set 11 | graham
# Processing Record 17 of Set 11 | abha
# Processing Record 18 of Set 11 | baykit
# Processing Record 19 of Set 11 | ottawa
# Processing Record 20 of Set 11 | sakakah
# Processing Record 21 of Set 11 | altagracia de orituco
# Processing Record 22 of Set 11 | kurilsk
# Processing Record 23 of Set 11 | luwuk
# Processing Record 24 of Set 11 | aniva
# Processing Record 25 of Set 11 | gobabis
# Processing Record 26 of Set 11 | finnsnes
# Processing Record 27 of Set 11 | vestmannaeyjar
# Processing Record 28 of Set 11 | mount isa
# Processing Record 29 of Set 11 | sisimiut
# Processing Record 30 of Set 11 | luchegorsk
# Processing Record 31 of Set 11 | strezhevoy
# Processing Record 32 of Set 11 | north platte
# Processing Record 33 of Set 11 | kalanguy
# Processing Record 34 of Set 11 | toucheng
# Processing Record 35 of Set 11 | chase
# Processing Record 36 of Set 11 | manali
# Processing Record 37 of Set 11 | kalat
# Processing Record 38 of Set 11 | puerto ayacucho
# Processing Record 39 of Set 11 | bama
# Processing Record 40 of Set 11 | dedovichi
# Processing Record 41 of Set 11 | isiro
# Processing Record 42 of Set 11 | ambilobe
# Processing Record 43 of Set 11 | moose factory
# Processing Record 44 of Set 11 | alyth
# Processing Record 45 of Set 11 | kropotkin
# Processing Record 46 of Set 11 | campbell river
# Processing Record 47 of Set 11 | muros
# Processing Record 48 of Set 11 | kochi
# Processing Record 49 of Set 11 | sonoita
# Processing Record 50 of Set 11 | urzhum
# Processing Record 1 of Set 12 | fallon
# Processing Record 2 of Set 12 | zhigalovo
# Processing Record 3 of Set 12 | barcelos
# Processing Record 4 of Set 12 | san ramon
# Processing Record 5 of Set 12 | ilheus
# Processing Record 6 of Set 12 | linjiang
# Processing Record 7 of Set 12 | payo
# Processing Record 8 of Set 12 | cabras
# Processing Record 9 of Set 12 | cheney
# Processing Record 10 of Set 12 | kampong thum
# Processing Record 11 of Set 12 | safford
# Processing Record 12 of Set 12 | rochester
# Processing Record 13 of Set 12 | grieskirchen
# Processing Record 14 of Set 12 | hasaki
# Processing Record 15 of Set 12 | new plymouth
# Processing Record 16 of Set 12 | dicabisagan
# Processing Record 17 of Set 12 | chota
# Processing Record 18 of Set 12 | lata
# Processing Record 19 of Set 12 | tezu
# Processing Record 20 of Set 12 | gornopravdinsk
# Processing Record 21 of Set 12 | shepsi
# Processing Record 22 of Set 12 | maceio
# Processing Record 23 of Set 12 | kununurra
# Processing Record 24 of Set 12 | artyom
# Processing Record 25 of Set 12 | mayor pablo lagerenza
# Processing Record 26 of Set 12 | palmer
# Processing Record 27 of Set 12 | bonnyville
# Processing Record 28 of Set 12 | grand-lahou
# Processing Record 29 of Set 12 | tamale
# Processing Record 30 of Set 12 | vao
# Processing Record 31 of Set 12 | harnosand
# Processing Record 32 of Set 12 | west bay
# Processing Record 33 of Set 12 | kudal
# Processing Record 34 of Set 12 | pitsunda
# Processing Record 35 of Set 12 | kostomuksha
# Processing Record 36 of Set 12 | whitehorse
# Processing Record 37 of Set 12 | panaba
# Processing Record 38 of Set 12 | codrington
# Processing Record 39 of Set 12 | troitskoye
# Processing Record 40 of Set 12 | la asuncion
# Processing Record 41 of Set 12 | pangnirtung
# Processing Record 42 of Set 12 | jingdezhen
# Processing Record 43 of Set 12 | la ronge
# Processing Record 44 of Set 12 | zeya
# Processing Record 45 of Set 12 | khandyga
# Processing Record 46 of Set 12 | kaiyuan
# Processing Record 47 of Set 12 | moron
# Processing Record 48 of Set 12 | cordoba
# Processing Record 49 of Set 12 | rorvik
# Processing Record 50 of Set 12 | mastic beach
# Processing Record 1 of Set 13 | saint anthony
# Processing Record 2 of Set 13 | zhezkazgan
# Processing Record 3 of Set 13 | pirovskoye
# Processing Record 4 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 5 of Set 13 | izyum
# Processing Record 6 of Set 13 | linhares
# Processing Record 7 of Set 13 | qiryat gat
# Processing Record 8 of Set 13 | bratsk
# Processing Record 9 of Set 13 | atlantic city
# Processing Record 10 of Set 13 | puerto asis
# Processing Record 11 of Set 13 | shamary
# Processing Record 12 of Set 13 | korla
# Processing Record 13 of Set 13 | esso
# Processing Record 14 of Set 13 | leeston
# Processing Record 15 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 13 | tortona
# Processing Record 17 of Set 13 | niono
# Processing Record 18 of Set 13 | snasa
# Processing Record 19 of Set 13 | amuntai
# Processing Record 20 of Set 13 | maragogi
# Processing Record 21 of Set 13 | gat
# Processing Record 22 of Set 13 | mawlaik
# Processing Record 23 of Set 13 | azare
# Processing Record 24 of Set 13 | avera
# Processing Record 25 of Set 13 | lensk
# Processing Record 26 of Set 13 | jiaojiang
# Processing Record 27 of Set 13 | bone
# Processing Record 28 of Set 13 | sabaudia
# Processing Record 29 of Set 13 | vila franca do campo
# Processing Record 30 of Set 13 | basco
# Processing Record 31 of Set 13 | namatanai
# Processing Record 32 of Set 13 | teseney
# Processing Record 33 of Set 13 | winnemucca
# Processing Record 34 of Set 13 | kalmar
# Processing Record 35 of Set 13 | aykhal
# Processing Record 36 of Set 13 | evensk
# Processing Record 37 of Set 13 | poenarii-burchi
# City not found. Skipping...
# Processing Record 38 of Set 13 | eucaliptus
# Processing Record 39 of Set 13 | ngunguru
# Processing Record 40 of Set 13 | kidal
# Processing Record 41 of Set 13 | westlock
# Processing Record 42 of Set 13 | lida
# Processing Record 43 of Set 13 | boli
# Processing Record 44 of Set 13 | mackenzie
# Processing Record 45 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 13 | tralee
# Processing Record 47 of Set 13 | conakry
# Processing Record 48 of Set 13 | valkeala
# Processing Record 49 of Set 13 | belaya gora
# Processing Record 50 of Set 13 | trincomalee
# Processing Record 1 of Set 14 | chulumani
# Processing Record 2 of Set 14 | miramar
# Processing Record 3 of Set 14 | caravelas
# Processing Record 4 of Set 14 | pizarro
# Processing Record 5 of Set 14 | tolaga bay
# Processing Record 6 of Set 14 | henties bay
# Processing Record 7 of Set 14 | ust-maya
# Processing Record 8 of Set 14 | rivne
# Processing Record 9 of Set 14 | staryy nadym
# Processing Record 10 of Set 14 | birjand
# Processing Record 11 of Set 14 | pendleton
# Processing Record 12 of Set 14 | bandarbeyla
# Processing Record 13 of Set 14 | maxixe
# Processing Record 14 of Set 14 | luganville
# Processing Record 15 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 14 | casas grandes
# Processing Record 17 of Set 14 | santiago
# Processing Record 18 of Set 14 | lopatyn
# Processing Record 19 of Set 14 | sioux lookout
# Processing Record 20 of Set 14 | san cristobal
# Processing Record 21 of Set 14 | bundaberg
# Processing Record 22 of Set 14 | kabanjahe
# Processing Record 23 of Set 14 | mon
# Processing Record 24 of Set 14 | nova bystrice
# Processing Record 25 of Set 14 | adzope
# Processing Record 26 of Set 14 | cooma
# Processing Record 27 of Set 14 | glace bay
# Processing Record 28 of Set 14 | rawson
# Processing Record 29 of Set 14 | keetmanshoop
# Processing Record 30 of Set 14 | filadelfia
# Processing Record 31 of Set 14 | melekhovo
# Processing Record 32 of Set 14 | abalak
# Processing Record 33 of Set 14 | ye
# City not found. Skipping...
# Processing Record 34 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 14 | ashtian
# Processing Record 36 of Set 14 | den helder
# Processing Record 37 of Set 14 | kathu
# Processing Record 38 of Set 14 | klyuchi
# Processing Record 39 of Set 14 | gisborne
# Processing Record 40 of Set 14 | sorland
# Processing Record 41 of Set 14 | tete
# Processing Record 42 of Set 14 | rocha
# Processing Record 43 of Set 14 | hazaribag
# Processing Record 44 of Set 14 | bilma
# Processing Record 45 of Set 14 | sulangan
# Processing Record 46 of Set 14 | tsumeb
# Processing Record 47 of Set 14 | dehui
# Processing Record 48 of Set 14 | batsfjord
# Processing Record 49 of Set 14 | chupei
# City not found. Skipping...
# Processing Record 50 of Set 14 | manbij
# Processing Record 1 of Set 15 | paita
# Processing Record 2 of Set 15 | vanavara
# Processing Record 3 of Set 15 | rongcheng
# Processing Record 4 of Set 15 | todos santos
# Processing Record 5 of Set 15 | aasiaat
# Processing Record 6 of Set 15 | victor harbor
# Processing Record 7 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 15 | mercedes
# Processing Record 9 of Set 15 | zhanakorgan
# Processing Record 10 of Set 15 | shirokiy
# Processing Record 11 of Set 15 | sangar
# Processing Record 12 of Set 15 | ust-ilimsk
# Processing Record 13 of Set 15 | rio gallegos
# Processing Record 14 of Set 15 | carroll
# Processing Record 15 of Set 15 | pietarsaari
# Processing Record 16 of Set 15 | myrtle beach
# Processing Record 17 of Set 15 | adrar
# Processing Record 18 of Set 15 | manokwari
# Processing Record 19 of Set 15 | lorengau
# Processing Record 20 of Set 15 | mildura
# Processing Record 21 of Set 15 | dhidhdhoo
# Processing Record 22 of Set 15 | nishihara
# Processing Record 23 of Set 15 | garowe
# Processing Record 24 of Set 15 | maralal
# Processing Record 25 of Set 15 | marzuq
# Processing Record 26 of Set 15 | zamania
# Processing Record 27 of Set 15 | zharkovskiy
# Processing Record 28 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 15 | dongsheng
# Processing Record 30 of Set 15 | jadu
# Processing Record 31 of Set 15 | batagay-alyta
# Processing Record 32 of Set 15 | pailon
# Processing Record 33 of Set 15 | batagay
# Processing Record 34 of Set 15 | portland
# Processing Record 35 of Set 15 | road town
# Processing Record 36 of Set 15 | merano
# Processing Record 37 of Set 15 | desaguadero
# Processing Record 38 of Set 15 | agbor
# Processing Record 39 of Set 15 | jalu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Ribeira Grande  38.52  -28.70     60.80        77          40       13.87
# 1      Butaritari   3.07  172.79     81.25        76          94       15.84
# 2  Virginia Beach  36.85  -75.98     72.00        73          75        4.70
# 3     Nakhon Thai  17.10  100.84     72.10        86           0        3.00
# 4         Dubuque  42.48  -90.87     71.01        44           7        8.01
# 5         Lincoln  40.80  -96.67     73.00        35           1        9.17
# 6  Saint-Philippe -21.36   55.77     73.40        73           0       14.99
# 7    Puerto Ayora  -0.74  -90.35     75.20        73          75       12.75
# 8          Avarua -21.21 -159.78     73.40        88          98        8.77
# 9      Vila Velha -20.33  -40.29     79.00        74          40       16.11
#
#   Country Current Description
# 0      PT    scattered clouds
# 1      KI     overcast clouds
# 2      US       broken clouds
# 3      TH           clear sky
# 4      US           clear sky
# 5      US           clear sky
# 6      RE           clear sky
# 7      EC       broken clouds
# 8      CK     overcast clouds
# 9      BR    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ribeira Grande      PT  38.52  -28.70     60.80        77          40
# 1        Butaritari      KI   3.07  172.79     81.25        76          94
# 2    Virginia Beach      US  36.85  -75.98     72.00        73          75
# 3       Nakhon Thai      TH  17.10  100.84     72.10        86           0
# 4           Dubuque      US  42.48  -90.87     71.01        44           7
# ..              ...     ...    ...     ...       ...       ...         ...
# 679       Road Town      VG  18.42  -64.62     86.00        66          40
# 680          Merano      IT  46.67   11.16     48.99        93           0
# 681     Desaguadero      PE -16.57  -69.04     60.40        30           0
# 682           Agbor      NG   6.25    6.19     79.45        70          47
# 683            Jalu      LY  29.03   21.55     69.73        51          99
#
#      Wind Speed Current Description
# 0         13.87    scattered clouds
# 1         15.84     overcast clouds
# 2          4.70       broken clouds
# 3          3.00           clear sky
# 4          8.01           clear sky
# ..          ...                 ...
# 679        8.05    scattered clouds
# 680        1.12           clear sky
# 681       15.64           clear sky
# 682        1.54    scattered clouds
# 683        7.23     overcast clouds
#
# [684 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
